# %% [markdown]
# <a href="https://colab.research.google.com/github/Surya2004-janardhan/colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("/content/dataset.csv")
dataset
# Out:
#      34    30987
# 0  35.0  30988.0
# 1  36.0      NaN
# 2  37.0  30990.0
# 3  38.0  30991.0
# 4   NaN  30992.0
# 5  40.0  30993.0
# 6  41.0      NaN
# 7   NaN  30995.0
# 8  43.0  30996.0

# %%
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values
print('Independent variable(X):',X)

print('Independent variable(Y):',Y)
# Out:
# Independent variable(X): [[35.]
#  [36.]
#  [37.]
#  [38.]
#  [nan]
#  [40.]
#  [41.]
#  [nan]
#  [43.]]
# Independent variable(Y): [30988.    nan 30990. 30991. 30992. 30993.    nan 30995. 30996.]

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan,strategy="median")
X = imp.fit_transform(X)
Y = Y.reshape(-1,1)
Y = imp.fit_transform(Y)
Y = Y.reshape(-1)
print(X)
print(Y)
# Out:
# [[35.]
#  [36.]
#  [37.]
#  [38.]
#  [38.]
#  [40.]
#  [41.]
#  [38.]
#  [43.]]
# [30988. 30992. 30990. 30991. 30992. 30993. 30992. 30995. 30996.]

# %%
x_df=pd.DataFrame(X,columns=dataset.columns[:-1])
y_df=pd.DataFrame(Y,columns=[dataset.columns[-1]])

combined_data =pd.concat([x_df,y_df],axis=1)
print("combined_data:")
print(combined_data)
# Out:
# combined_data:
#      34    30987
# 0  35.0  30988.0
# 1  36.0  30992.0
# 2  37.0  30990.0
# 3  38.0  30991.0
# 4  38.0  30992.0
# 5  40.0  30993.0
# 6  41.0  30992.0
# 7  38.0  30995.0
# 8  43.0  30996.0

# %%
combined_df = pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("Combined DataFrame:")
print(combined_df.head())
# Out:
# Combined DataFrame:
#      34    30987
# 0  35.0  30988.0
# 1  36.0  30992.0
# 2  37.0  30990.0
# 3  38.0  30991.0
# 4  38.0  30992.0
