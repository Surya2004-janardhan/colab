# %% [markdown]
# <a href="https://colab.research.google.com/github/Surya2004-janardhan/colab/blob/main/Exper9%20(no%20data%20set%20included%20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
data = pd.read_csv('Wholesale customers data.csv')
# Display the first few rows of the dataset
data.head()
# Import the necessary library for feature scaling
from sklearn.preprocessing import normalize
# Normalize the data
data_scaled = normalize(data)
# Convert the normalized data array back to a DataFrame
data_scaled = pd.DataFrame(data_scaled, columns=data.columns)
# Display the first few rows of the scaled data
data_scaled.head()
# Import necessary library
import scipy.cluster.hierarchy as shc
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3612926502de> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 # Load the dataset
# ----> 6 data = pd.read_csv('Wholesale customers data.csv')
#       7 # Display the first few rows of the dataset
#       8 data.head()
#
# ...

# %%
# Set the figure size for the plot
plt.figure(figsize=(10, 7))
# Set the title of the plot
plt.title("Dendrogram")
# Compute and plot the dendrogram using Ward's method
dendrogram = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
# Display the plot
plt.show()
# Set the figure size for the plot
plt.figure(figsize=(10, 7))
# Set the title of the plot
plt.title("Dendrograms")
# Compute and plot the dendrogram using Ward's method
dendrogram = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
# Add a horizontal line at y=6 with red dashed linestyle
plt.axhline(y=6, color='r', linestyle='--')
# Display the plot
plt.show()
# Set the figure size for the plot
plt.figure(figsize=(10, 7))
# Set the title of the plot
plt.title("Dendrograms")
# Compute and plot the dendrogram using Ward's method
dendrogram = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60f9f964bcf5> in <cell line: 6>()
#       4 plt.title("Dendrogram")
#       5 # Compute and plot the dendrogram using Ward's method
# ----> 6 dendrogram = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
#       7 # Display the plot
#       8 plt.show()
#
# NameError: name 'shc' is not defined

# %%
# Add a horizontal line at y=6 with red dashed linestyle
plt.axhline(y=6, color='r', linestyle='--')
# Display the plot
plt.show()
# Set the figure size for the plot
plt.figure(figsize=(10, 7))
# Scatter plot of the data points with Milk on x-axis and Grocery on y-axis
plt.scatter(data_scaled['Milk'], data_scaled['Grocery'], c=cluster.labels_, cmap='viridis')
# Set labels and title
plt.xlabel('Milk')
plt.ylabel('Grocery')
plt.title('Clusters Visualization')
# Display the plot
plt.colorbar(label='Cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6d8e8c9adec7> in <cell line: 8>()
#       6 plt.figure(figsize=(10, 7))
#       7 # Scatter plot of the data points with Milk on x-axis and Grocery on y-axis
# ----> 8 plt.scatter(data_scaled['Milk'], data_scaled['Grocery'], c=cluster.labels_, cmap='viridis')
#       9 # Set labels and title
#      10 plt.xlabel('Milk')
#
# NameError: name 'data_scaled' is not defined
